# %% [markdown]
# <a href="https://colab.research.google.com/github/avabaral-gif/Python/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rules of creating variables:
# 1. naming - should be proper and it has to efine what we are storing inside the variable
# 2. Special characters are not allowed you can only use underscore(_)
# 3. Spaces are also not allowed
# 4. Python is case sensitive
# 5. for multiple words in the variable we can use camel case method
# 6. we can't start the variable name wit the speacial character or number, we can use underscore or letter.

# %%
# creating variable names
number = 12345678
name_of_book = "python"
name ="Ava"
Name = "Yukta"
NAME = "Saanvi"
print(name)
# Out:
# Ava

# %% [markdown]
# Data types: we have 4 types of data types
# 1. int- integer values (both positive and negative values)
# 2. float - decimal values
# 3. string- combination of letters
# 4. boolean - True, False

# %%
decimals = 1.2
numbers = 3
Words = "Hi"
R = True
print(decimals)
print(numbers)
print(Words)
print(R)
# Out:
# 1.2
# 3
# Hi
# True

# %%
FLL = "Bio-Force"
Name ="Ava"
Last_Name = "Baral"
School_Name = "Mesa Verde Middle School"
Sports = "Tennis and swimming"
Clubs = "Math Club "
Mom =  "Sonia"
Dad = "Rashmi"
Best_Friend = "Izel"
Instrument = "piano and violin"

print("My name is",Name,"  and I go to ",School_Name)
print(Name)
print(FLL)
print(Last_Name)
print(School_Name)
print(Sports)
print(Clubs)
print(Mom)
print(Dad)
print(Best_Friend)
print(Instrument)
# Out:
# My name is Ava   and I go to  Mesa Verde Middle School
# Ava
# Bio-Force
# Baral
# Mesa Verde Middle School
# Tennis and swimming
# Math Club
# Sonia
# Rashmi
# Izel
# piano and violin

# %%
word = "book"
num = 345678
che = '6'
isRaining = True
fle = 23456.0
print(type(word))
print(type(num))
print(type(che))
print(type(isRaining))
print(type(fle))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %%
#1
student_name = "Ava Baral"
student_age = 12
student_grade = "7th Grade"

#2
brand = "Apple"
model = "iPhone 15"
price = 799.99

print(brand)
print(model)
print(price)

print(type(brand))
print(type(model))
print(type(price))

#3
name = "Gina"
account_number = 123456
balance = 2500.50

print(name)
print(account_number)
print(balance)

print(type(balance))


#4
product_name = "Headphones"
quantity = 2
price = 49.99

print(product_name)
print(quantity)
print(price)

#5
name = "Ava"
employee_id = 1034
salary = 6500000
is_permanent = True

print(name)
print(employee_id)
print(salary)
print(is_permanent)

print(type(name))
print(type(employee_id))
print(type(salary))
print(type(is_permanent))


#6
name = " Lawrence"
runs = 13848
average = 58.67

print(name)
print(runs)
print(average)

print(type(name))
print(type(runs))
print(type(average))


#7
movie = "Avatar"
tickets = 4
price = 12.50

print(movie)
print(tickets)
print(price)

#8
city = "San Diego"
temp = 72.5
is_raining = False

print(city)
print(temp)
print(is_raining)

print(type(city))
print(type(temp))
print(type(is_raining))

#9
name = "Emily"
fee = 1200
status = "Paid"

print(name)
print(fee)
print(status)

print(type(name))
print(type(fee))
print(type(status))


#10
student_name = "Ava"
workshop_name = "Robotics 101"
registration_fee = 75.00
registration_status = "Registered"

print(student_name)
print(workshop_name)
print(registration_fee)
print(registration_status)

print(type(student_name))
print(type(workshop_name))
print(type(registration_fee))
print(type(registration_status))
# Out:
# Apple
# iPhone 15
# 799.99
# <class 'str'>
# <class 'str'>
# <class 'float'>
# Gina
# 123456
# 2500.5
# <class 'float'>
# Headphones
# 2
# 49.99
# Ava
# 1034
# 6500000
# True
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
#  Lawrence
# 13848
# 58.67
# <class 'str'>
# <class 'int'>
# <class 'float'>
# Avatar
# 4
# 12.5
# San Diego
# 72.5
# False
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# Emily
# 1200
# Paid
# <class 'str'>
# <class 'int'>
# <class 'str'>
# Ava
# Robotics 101
# 75.0
# Registered
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
